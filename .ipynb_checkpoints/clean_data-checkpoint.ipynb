# %%
import pandas as pd
train = pd.read_csv("data/Twitter/hate_twitter/train_E6oV3lV.csv")
test = pd.read_csv('data/Twitter/hate_twitter/test_tweets_anuFYb8.csv')

# %%
train.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %%
train.shape
# Out:
# (31962, 3)

# %%
test_str = "@user @user thanks for #lyft credit i can't "
re.findall(r"#(\w+)", test_str)
# Out:
# ['lyft']

# %%
import re
from sklearn.utils import resample

FLAGS = re.MULTILINE | re.DOTALL


def hashtag(text):
    text = text.group()
    hashtag_body = text[1:]
    if hashtag_body.isupper():
        result = u"<hashtag> {} <allcaps>".format(hashtag_body)
    else:
        result = " ".join(["<hashtag>"] + re.split(u"(?=[A-Z])", hashtag_body, flags=FLAGS))
    return result

def allcaps(text):
    text = text.group()
    return text.lower() + " <allcaps>"


def tokenize(text):
    # Different regex parts for smiley faces
    eyes = r"[8:=;]"
    nose = r"['`\-]?"

    # function so code less repetitive
    def re_sub(pattern, repl):
        return re.sub(pattern, repl, text, flags=FLAGS)

    text = re_sub(r"https?:\/\/\S+\b|www\.(\w+\.)+\S*", "<url>")
    text = re_sub(r"/"," / ")
    text = re_sub(r"@\w+", "<user>")
    text = re_sub(r"{}{}[)dD]+|[)dD]+{}{}".format(eyes, nose, nose, eyes), "<smile>")
    text = re_sub(r"{}{}p+".format(eyes, nose), "<lolface>")
    text = re_sub(r"{}{}\(+|\)+{}{}".format(eyes, nose, nose, eyes), "<sadface>")
    text = re_sub(r"{}{}[\/|l*]".format(eyes, nose), "<neutralface>")
    text = re_sub(r"<3","<heart>")
    text = re_sub(r"[-+]?[.\d]*[\d]+[:,.\d]*", "<number>")
    text = re_sub(r"#\S+", hashtag)
    text = re_sub(r"([!?.]){2,}", r"\1 <repeat>")
    text = re_sub(r"\b(\S*?)(.)\2{2,}\b", r"\1\2 <elong>")

    ## -- I just don't understand why the Ruby script adds <allcaps> to everything so I limited the selection.
    # text = re_sub(r"([^a-z0-9()<>'`\-]){2,}", allcaps)
    text = re_sub(r"([A-Z]){2,}", allcaps)

    return text.lower()


def  clean_text(df, text_field):
    df["hash_tag"] = df[text_field].apply(lambda elem: re.findall(r"#(\w+)", elem.lower()))  
    df["clean_tweet"] = df[text_field].str.lower()
    df["clean_tweet"] = df[text_field].apply(lambda elem: re.sub(r"(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", elem)) 
    df["tokenized_tweet"] = df[text_field].apply(tokenize)
    return df
test_clean = clean_text(test, "tweet")
train_clean = clean_text(train, "tweet")


# Upsampling the Minority Class

train_majority = train_clean[train_clean.label==0]
train_minority = train_clean[train_clean.label==1]
train_minority_upsampled = resample(train_minority, 
                                 replace=True,    
                                 n_samples=len(train_majority),   
                                 random_state=123)



train_upsampled = pd.concat([train_minority_upsampled, train_majority])
train_upsampled['label'].value_counts()
# Out:
# 0    29720
# 1    29720
# Name: label, dtype: int64

# %%
train_clean.head()
# Out:
#    id  label                                              tweet  \
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation
#
#                           hash_tag  \
# 0                            [run]
# 1  [lyft, disapointed, getthanked]
# 2                               []
# 3                          [model]
# 4                     [motivation]
#
#                                          clean_tweet
# 0    when a father is dysfunctional and is so sel...
# 1    thanks for lyft credit i cant use cause they...
# 2                                bihday your majesty
# 3  model   i love u take with u all the time in u...
# 4               factsguide society now    motivation

# %%
train_clean[train_clean["hash_tag"].apply(lambda x: len(x) > 0)]
# Out:
#           id  label                                              tweet  \
# 0          1      0   @user when a father is dysfunctional and is s...
# 1          2      0  @user @user thanks for #lyft credit i can't us...
# 3          4      0  #model   i love u take with u all the time in ...
# 4          5      0             factsguide: society now    #motivation
# 5          6      0  [2/2] huge fan fare and big talking before the...
# ...      ...    ...                                                ...
# 31953  31954      0  good morning #instagram #shower #water #berlin...
# 31954  31955      0  #holiday   bull up: you will dominate your bul...
# 31955  31956      0  less than 2 weeks ð
# ðð¼ð¹ððµ @us...
# 31958  31959      0    to see nina turner on the airwaves trying to...
# 31960  31961      1  @user #sikh #temple vandalised in in #calgary,...
#
#                                                 hash_tag  \
# 0                                                  [run]
# 1                        [lyft, disapointed, getthanked]
# 3                                                [model]
# 4                                           [motivation]
# 5                                       [allshowandnogo]
# ...                                                  ...
# 31953  [instagram, shower, water, berlin, berlincityg...
# 31954                                          [holiday]
# 31955     [ibiza, bringiton, mallorca, holidays, summer]
# 31958                                 [shame, imwithher]
# 31960                       [sikh, temple, calgary, wso]
#
#                                              clean_tweet  \
# 0        when a father is dysfunctional and is so sel...
# 1        thanks for lyft credit i cant use cause they...
# 3      model   i love u take with u all the time in u...
# 4                   factsguide society now    motivation
# 5      22 huge fan fare and big talking before they l...
# ...                                                  ...
# 31953  good morning instagram shower water berlin ber...
# 31954  holiday   bull up you will dominate your bull ...
# 31955  less than 2 weeks   ibizabringitonmallorcaholi...
# 31958    to see nina turner on the airwaves trying to...
# 31960   sikh temple vandalised in in calgary wso cond...
#
#                                          tokenized_tweet
# 0       <user> when a father is dysfunctional and is ...
# 1      <user> <user> thanks for <hashtag> lyft credit...
# 3      <hashtag> model  <elong>i love u take with u a...
# 4        factsguide: society now    <hashtag> motivation
# 5      [<number> / <number>] huge fan fare and big ta...
# ...                                                  ...
# 31953  good morning <hashtag> instagram <hashtag> sho...
# 31954  <hashtag> holiday  <elong>bull up: you will do...
# 31955  less than <number> weeks ð
# ðð¼ð¹ðð...
# 31958    to see nina turner on the airwaves trying to...
# 31960  <user> <hashtag> sikh <hashtag> temple vandali...
#
# [23456 rows x 6 columns]

# %%
train_upsampled['clean_tweet'][5]
# Out:
# '22 huge fan fare and big talking before they leave chaos and pay disputes when they get there allshowandnogo  '

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1,2 , figsize=(16,8))
text_pos = " ".join(train_clean['clean_tweet'][train.label == 0])
text_neg = " ".join(train_clean['clean_tweet'][train.label == 1])
train_cloud_pos = WordCloud(collocations = False, background_color = 'white').generate(text_pos)
train_cloud_neg = WordCloud(collocations = False, background_color = 'black').generate(text_neg)
axs[0].imshow(train_cloud_pos, interpolation='bilinear')
axs[0].axis('off')
axs[0].set_title('Non-Hate Comments')
axs[1].imshow(train_cloud_neg, interpolation='bilinear')
axs[1].axis('off')
axs[1].set_title('Hate Comments')

plt.show()

# %%
train_upsampled.to_csv("train_upsampled.csv")

# %% [markdown]
# # Feature Extraction

# %%
# https://scikit-learn.org/stable/modules/feature_extraction.html#text-feature-extraction


import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer # TF-IDF
from sklearn.feature_extraction.text import TfidfTransformer # TF-IDF
from sklearn.feature_extraction.text import CountVectorizer # BoW
from sklearn.metrics import f1_score, accuracy_score
