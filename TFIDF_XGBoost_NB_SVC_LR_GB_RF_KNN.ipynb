# %%
#!pip install xgboost

# %%
import xgboost as xgb
import numpy as np
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

from sklearn.metrics import f1_score, accuracy_score, recall_score, classification_report
from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold, cross_val_score

from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB

# %%
train_df = pd.read_csv('data/Twitter/hate_twitter/hate_train.csv')
val_df = pd.read_csv('data/Twitter/hate_twitter/hate_val.csv')
test_df = pd.read_csv('data/Twitter/hate_twitter/hate_test.csv')

# %%
# Check and drop na values in clean_tweet column
train_df[train_df['clean_tweet'].isnull()]

train_df = train_df[train_df['clean_tweet'].notna()]
val_df = val_df[val_df['clean_tweet'].notna()]
test_df = test_df[test_df['clean_tweet'].notna()]

# %%
train_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1     id  label  \
# 0       27857         27857  27858      0
# 1       31205         31205  31206      0
# 2        8440          8440   8441      0
# 3        5005          5005   5006      1
# 4        3898          3898   3899      0
#
#                                                tweet  \
# 0  omg. omg. omg.  yay! i found it, and at a wond...
# 1  #payintheusa   polar bear climb racing: angry ...
# 2  #trainhard   polar bear climb racing: angry po...
# 3                he should turn in his resignation.
# 4  ððð . . happy bihday!! to hajime hoso...
#
#                        hash_tag  \
# 0  ['segasaturn', 'throwbackâ']
# 1               ['payintheusa']
# 2                 ['trainhard']
# 3                            []
# 4        ['bihday', '30æ', 'ã']
#
#                                          clean_tweet  \
# 0  omg omg omg yay found wonderful price segasatu...
# 1  payintheusa polar bear climb racing angry pola...
# 2  trainhard polar bear climb racing angry polar ...
# 3                                   turn resignation
# 4       happy bihday hajime hosogai bihday bihday 30
#
#                                      tokenized_tweet  \
# 0  omg. omg. omg.  yay! i found it, and at a wond...
# 1  <hashtag> payintheusa  <elong>polar bear climb...
# 2  <hashtag> trainhard  <elong>polar bear climb r...
# 3                he should turn in his resignation.
# 4  ððð . . happy bihday! <repeat> to haj...
#
#                                 tokenized_tweet_NLTK
# 0  omg omg omg yay found wonderful price segasatu...
# 1  payintheusa polar bear climb racing angry pola...
# 2  trainhard polar bear climb racing angry polar ...
# 3                                   turn resignation
# 4  . . happy bihday hajime hosogai . . . bihday b...

# %%
x_train = train_df['clean_tweet']
y_train = train_df['label']

x_test = test_df['clean_tweet']
y_test = test_df['label']

x_val = val_df['clean_tweet']
y_val = val_df['label']

# %% [markdown]
# # TFIDF+XGBoost

# %%
pipeline_xgb = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf',  TfidfTransformer()),
    ('nb', xgb.XGBClassifier(use_label =False)),])

# %%
model_xgb = pipeline_xgb.fit(x_train, y_train)
model = pipeline_xgb.fit(x_train, y_train)
# Out:
# [23:24:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:24:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %%
y_test_predict = model.predict(x_test)
y_val_predict = model.predict(x_val)

print('--'* 20)
print('Validation result')
print('Recall_Score: ', recall_score(y_val, y_val_predict))
print('F1_Score: ',f1_score(y_val, y_val_predict))
print('Accuracy_Score: ', accuracy_score(y_val, y_val_predict))



print('--'* 20)
print('Test result')
print('Recall_Score: ',recall_score(y_test, y_test_predict))
print('F1_Score: ',f1_score(y_test, y_test_predict))
print('Accuracy_Score: ', accuracy_score(y_test, y_test_predict))
# Out:
# ----------------------------------------
# Validation result
# Recall_Score:  0.3313953488372093
# F1_Score:  0.4840764331210191
# Accuracy_Score:  0.9492693110647181
# ----------------------------------------
# Test result
# Recall_Score:  0.40809968847352024
# F1_Score:  0.5598290598290598
# Accuracy_Score:  0.9570116861435726

# %%
def evaluate_model(model):
    y_test_predict = model.predict(x_test)
    y_val_predict = model.predict(x_val)

    print('--'* 20)
    print('Validation result')
    print('Recall_Score: ', recall_score(y_val, y_val_predict))
    print('F1_Score: ',f1_score(y_val, y_val_predict))
    print('Accuracy_Score: ', accuracy_score(y_val, y_val_predict))



    print('--'* 20)
    print('Test result')
    print('Recall_Score: ',recall_score(y_test, y_test_predict))
    print('F1_Score: ',f1_score(y_test, y_test_predict))
    print('Accuracy_Score: ', accuracy_score(y_test, y_test_predict))

# %%
evaluate_model(model_xgb)
# Out:
# ----------------------------------------
# Validation result
# Recall_Score:  0.3313953488372093
# F1_Score:  0.4840764331210191
# Accuracy_Score:  0.9492693110647181
# ----------------------------------------
# Test result
# Recall_Score:  0.40809968847352024
# F1_Score:  0.5598290598290598
# Accuracy_Score:  0.9570116861435726

# %%
# RepeatedKFOLD
def k_fold(pipeline):
    print('--'*20)
    print('---RepeatedKFOLD---')
    cv = RepeatedStratifiedKFold(n_splits = 5, n_repeats = 2, random_state =1)

    recall_score = cross_val_score(pipeline, x_train, y_train, cv=cv, scoring='recall', n_jobs=1)
    recall_score = np.mean(recall_score)

    f1_score = cross_val_score(pipeline, x_train, y_train, cv=cv, scoring='f1', n_jobs=1)
    f1_score = np.mean(f1_score)

    accuracy_score = cross_val_score(pipeline, x_train, y_train, cv=cv, scoring='accuracy', n_jobs=1)
    accuracy_score = np.mean(accuracy_score)
    print('--'* 20)
    print('RKFold_Recall_Score: ', recall_score)
    print('RKFold_F1_Score: ', f1_score)
    print('RKFold_Accuracy_Score: ', accuracy_score)

    print('--'* 20)

# %%
k_fold(pipeline_xgb)
# Out:
# ----------------------------------------
# ---RepeatedKFOLD---
# [23:25:23] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:25:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:25:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:25:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:25:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:25:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:25:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:25:43] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:25:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:25:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:25:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:25:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:25:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:26:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:26:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:26:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:26:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:26:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:26:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [23:26:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:26:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:26:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:26:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:26:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:26:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:26:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:26:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:26:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:26:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [23:26:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# ----------------------------------------
# RKFold_Recall_Score:  0.3637175209786675
# RKFold_F1_Score:  0.5087852726649534
# RKFold_Accuracy_Score:  0.9505816554809844
# ----------------------------------------

# %% [markdown]
# # TFIDF+SVC/Linear SVC

# %%
from sklearn.svm import SVC, LinearSVC

# %%
pipeline_svc = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf',  TfidfTransformer()),
    ('nb', SVC()),])
model_svc = pipeline_svc.fit(x_train, y_train)

evaluate_model(model_svc)
# k_fold(pipeline_svc)
# Out:
# ----------------------------------------
# Validation result
# Recall_Score:  0.42151162790697677
# F1_Score:  0.5846774193548387
# Accuracy_Score:  0.9569937369519833
# ----------------------------------------
# Test result
# Recall_Score:  0.43302180685358255
# F1_Score:  0.5914893617021276
# Accuracy_Score:  0.9599332220367279

# %%
pipeline_linear_svc = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf',  TfidfTransformer()),
    ('nb', LinearSVC(C=0.01)),])
model_linear_svc = pipeline_linear_svc.fit(x_train, y_train)

evaluate_model(model_linear_svc)
# k_fold(pipeline_linear_svc)
# Out:
# ----------------------------------------
# Validation result
# Recall_Score:  0.02616279069767442
# F1_Score:  0.05099150141643059
# Accuracy_Score:  0.930062630480167
# ----------------------------------------
# Test result
# Recall_Score:  0.04361370716510903
# F1_Score:  0.0835820895522388
# Accuracy_Score:  0.9359348914858097

# %% [markdown]
# # TFIDF+LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
pipeline_lr = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf',  TfidfTransformer()),
    ('nb', LogisticRegression()),])
model_lr = pipeline_lr.fit(x_train, y_train)

evaluate_model(model_lr)
k_fold(pipeline_lr)
# Out:
# ----------------------------------------
# Validation result
# Recall_Score:  0.2819767441860465
# F1_Score:  0.43595505617977526
# Accuracy_Score:  0.9475991649269311
# ----------------------------------------
# Test result
# Recall_Score:  0.2803738317757009
# F1_Score:  0.43062200956937796
# Accuracy_Score:  0.9503338898163606
# ----------------------------------------
# ---RepeatedKFOLD---
# ----------------------------------------
# RKFold_Recall_Score:  0.2430108179152765
# RKFold_F1_Score:  0.3858051711149444
# RKFold_Accuracy_Score:  0.9455257270693511
# ----------------------------------------

# %% [markdown]
# # TFIDF+GradientBoosting/RandomForest

# %%
from sklearn.ensemble  import GradientBoostingClassifier, RandomForestClassifier

# %%
pipeline_gb = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf',  TfidfTransformer()),
    ('nb', GradientBoostingClassifier()),])
model_gb = pipeline_gb.fit(x_train, y_train)

evaluate_model(model_gb)
k_fold(pipeline_gb)
# Out:
# ----------------------------------------
# Validation result
# Recall_Score:  0.2616279069767442
# F1_Score:  0.40268456375838924
# Accuracy_Score:  0.944258872651357
# ----------------------------------------
# Test result
# Recall_Score:  0.2866043613707165
# F1_Score:  0.4309133489461358
# Accuracy_Score:  0.9492904841402338
# ----------------------------------------
# ---RepeatedKFOLD---
# ----------------------------------------
# RKFold_Recall_Score:  0.2881225356384592
# RKFold_F1_Score:  0.43189157489685137
# RKFold_Accuracy_Score:  0.9472259507829979
# ----------------------------------------

# %%
pipeline_rf = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf',  TfidfTransformer()),
    ('nb', RandomForestClassifier()),])
model_rf = pipeline_rf.fit(x_train, y_train)

evaluate_model(model_rf)
k_fold(pipeline_rf)
# Out:
# ----------------------------------------
# Validation result
# Recall_Score:  0.5058139534883721
# F1_Score:  0.6432532347504621
# Accuracy_Score:  0.9597077244258873
# ----------------------------------------
# Test result
# Recall_Score:  0.5233644859813084
# F1_Score:  0.6511627906976744
# Accuracy_Score:  0.9624373956594324
# ----------------------------------------
# ---RepeatedKFOLD---
# ----------------------------------------
# RKFold_Recall_Score:  0.48603073501162675
# RKFold_F1_Score:  0.6380260149836923
# RKFold_Accuracy_Score:  0.9596420581655479
# ----------------------------------------

# %% [markdown]
# # Deal with data imbalance, upsample

# %%
from sklearn.utils import resample

# %%
train_majority = train_df[train_df.label==0]
train_minority = train_df[train_df.label==1]
train_minority_upsampled = resample(train_minority, 
                                 replace=True,    
                                 n_samples=len(train_majority),   
                                 random_state=123)
train_upsampled = pd.concat([train_minority_upsampled, train_majority])
train_upsampled['label'].value_counts()
# Out:
# 0    20776
# 1    20776
# Name: label, dtype: int64

# %%
x_train = train_upsampled['clean_tweet']
y_train = train_upsampled['label']

# %%
# XGBoost
pipeline_xgb = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf',  TfidfTransformer()),
    ('nb', xgb.XGBClassifier(use_label =False)),])
model_xgb = pipeline_xgb.fit(x_train, y_train)

evaluate_model(model_xgb)
k_fold(pipeline_xgb)
# Out:
# [01:08:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# ----------------------------------------
# Validation result
# Recall_Score:  0.6744186046511628
# F1_Score:  0.5679314565483475
# Accuracy_Score:  0.9263048016701462
# ----------------------------------------
# Test result
# Recall_Score:  0.7071651090342679
# F1_Score:  0.5646766169154229
# Accuracy_Score:  0.9269616026711185
# ----------------------------------------
# ---RepeatedKFOLD---
# [01:08:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:08:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:08:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:08:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:09:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:09:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:09:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:09:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:09:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:10:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:10:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:10:23] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:10:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:10:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:10:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:11:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:11:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [01:11:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:11:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:11:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:11:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:12:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:12:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:12:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:12:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:13:00] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:13:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:13:23] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:13:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:13:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# ----------------------------------------
# RKFold_Recall_Score:  0.8919184418971773
# RKFold_F1_Score:  0.9171481091025167
# RKFold_Accuracy_Score:  0.919438291009798
# ----------------------------------------

# %%
# SVC
pipeline_svc = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf',  TfidfTransformer()),
    ('nb', SVC()),])
model_svc = pipeline_svc.fit(x_train, y_train)

evaluate_model(model_svc)
# k_fold(pipeline_svc)
# Out:
# ----------------------------------------
# Validation result
# Recall_Score:  0.5087209302325582
# F1_Score:  0.660377358490566
# Accuracy_Score:  0.9624217118997912
# ----------------------------------------
# Test result
# Recall_Score:  0.5264797507788161
# F1_Score:  0.6706349206349206
# Accuracy_Score:  0.9653589315525877

# %%
# Logistic Regression
pipeline_lr = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf',  TfidfTransformer()),
    ('nb', LogisticRegression()),])
model_lr = pipeline_lr.fit(x_train, y_train)

evaluate_model(model_lr)
k_fold(pipeline_lr)
# Out:
# ----------------------------------------
# Validation result
# Recall_Score:  0.7151162790697675
# F1_Score:  0.6525198938992043
# Accuracy_Score:  0.9453027139874739
# ----------------------------------------
# Test result
# Recall_Score:  0.7757009345794392
# F1_Score:  0.6578599735799207
# Accuracy_Score:  0.9459515859766278
# ----------------------------------------
# ---RepeatedKFOLD---
# ----------------------------------------
# RKFold_Recall_Score:  0.9975211921580618
# RKFold_F1_Score:  0.9789589688959653
# RKFold_Accuracy_Score:  0.9785569847045679
# ----------------------------------------

# %%
# Gradient Boost
pipeline_gb = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf',  TfidfTransformer()),
    ('nb', GradientBoostingClassifier()),])
model_gb = pipeline_gb.fit(x_train, y_train)

evaluate_model(model_gb)
k_fold(pipeline_gb)
# Out:
# ----------------------------------------
# Validation result
# Recall_Score:  0.5465116279069767
# F1_Score:  0.5333333333333333
# Accuracy_Score:  0.9313152400835073
# ----------------------------------------
# Test result
# Recall_Score:  0.5950155763239875
# F1_Score:  0.5528219971056438
# Accuracy_Score:  0.9355175292153589
# ----------------------------------------
# ---RepeatedKFOLD---
# ----------------------------------------
# RKFold_Recall_Score:  0.6389344563237122
# RKFold_F1_Score:  0.7625601763502216
# RKFold_Accuracy_Score:  0.8005390489834054
# ----------------------------------------

# %%
# Random Forest
pipeline_rf = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf',  TfidfTransformer()),
    ('nb', RandomForestClassifier()),])
model_rf = pipeline_rf.fit(x_train, y_train)

evaluate_model(model_rf)
k_fold(pipeline_rf)
# Out:
# ----------------------------------------
# Validation result
# Recall_Score:  0.5843023255813954
# F1_Score:  0.6907216494845362
# Accuracy_Score:  0.9624217118997912
# ----------------------------------------
# Test result
# Recall_Score:  0.5700934579439252
# F1_Score:  0.6594594594594594
# Accuracy_Score:  0.960559265442404
# ----------------------------------------
# ---RepeatedKFOLD---
# ----------------------------------------
# RKFold_Recall_Score:  1.0
# RKFold_F1_Score:  0.9939615545538333
# RKFold_Accuracy_Score:  0.9939714043745541
# ----------------------------------------

# %% [markdown]
# # Pipeline

# %%
def tfidf_pipeline(train_df, test_df, val_df, ngram_range=(1,1)):
    '''
    Pipeline for TF-IDF based models training and evaluation
    '''
    cls = [LogisticRegression(),
           MultinomialNB(), 
           SVC(),
           LinearSVC(C=0.01),
           GradientBoostingClassifier(),
           xgb.XGBClassifier(use_label =False),
           RandomForestClassifier(n_estimators=200),
           KNeighborsClassifier(n_neighbors = 5)]
    
    result_all_dict = {}

    vectorizer = TfidfVectorizer(ngram_range=ngram_range)
    train_tfidf_model = vectorizer.fit_transform(train_df.clean_tweet)
    test_tfidf_model = vectorizer.transform(test_df.clean_tweet)
    val_tfidf_model = vectorizer.transform(val_df.clean_tweet)

    train_tfidf = pd.DataFrame(train_tfidf_model)

    test_actual = test_df.label
    val_actual = val_df.label
    i = 0
    accuracy = []
    cls_name = []

    for cl in cls:
        result_dict = {}
            
        model = cl.fit(train_tfidf_model,train_df.label)
        
        y_test_predict = model.predict(test_tfidf_model)
        y_val_predict = model.predict(val_tfidf_model)
        
        a = (100*accuracy_score(y_test_predict, lbl_actual))
        a = round(a,2)
        accuracy.append(a)
        cls_name.append(cl.__class__.__name__)
        
        print('--'* 20)
        print ("{}  Accuracy Score : {}%".format(cls_name[i],a))
        print('Recall_Score: ',recall_score(lbl_pred, lbl_actual))
        print('F1_Score: ',f1_score(lbl_pred, lbl_actual))
        print ( classification_report(lbl_pred, lbl_actual))
        
        
        result_dict["Validation Accuracy"] = accuracy_score(y_val_predict, val_actual)
        result_dict["Validation Binary Recall"] = recall_score(y_val_predict, val_actual)
        result_dict["Validation Macro Recall"] = recall_score(y_val_predict, val_actual, average='macro')
        result_dict["Validation Binary F1"] = f1_score(y_val_predict, val_actual)
        result_dict["Validation Macro F1"] = f1_score(y_val_predict, val_actual, average='macro')
        result_dict["Test Accuracy"] = accuracy_score(y_test_predict, test_actual)
        result_dict["Test Binary Recall"] = recall_score(y_test_predict, test_actual)
        result_dict["Test Macro Recall"] = recall_score(y_test_predict, test_actual, average='macro')
        result_dict["Test Binary F1"] = f1_score(y_test_predict, test_actual)
        result_dict["Test Macro F1"] = f1_score(y_test_predict, test_actual, average='macro')
        
        result_all_dict[cl.__class__.__name__] = result_dict
        
        i +=1
    
    return result_all_dict

# %% [markdown]
# ## Original data frame: Only Unigram

# %%
result_all_dict = tfidf_pipeline(train_df, test_df, val_df)
# Out:
# ----------------------------------------
# LogisticRegression  Accuracy Score : 95.03%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# MultinomialNB  Accuracy Score : 94.34%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# SVC  Accuracy Score : 95.99%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# LinearSVC  Accuracy Score : 93.59%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# GradientBoostingClassifier  Accuracy Score : 94.91%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# [16:29:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# ----------------------------------------
# XGBClassifier  Accuracy Score : 95.7%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# RandomForestClassifier  Accuracy Score : 96.37%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# KNeighborsClassifier  Accuracy Score : 95.22%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792

# %%
result_pd = pd.DataFrame.from_dict(result_all_dict, orient='index')
result_pd
# Out:
#                             Validation Accuracy  Validation Binary Recall  \
# LogisticRegression                     0.947599                  0.960396
# MultinomialNB                          0.939457                  0.982143
# SVC                                    0.956994                  0.953947
# LinearSVC                              0.930063                  1.000000
# GradientBoostingClassifier             0.943841                  0.871287
# XGBClassifier                          0.949269                  0.897638
# RandomForestClassifier                 0.959708                  0.868293
# KNeighborsClassifier                   0.945720                  0.833333
#
#                             Validation Macro Recall  Validation Binary F1  \
# LogisticRegression                         0.953860              0.435955
# MultinomialNB                              0.960548              0.275000
# SVC                                        0.955520              0.584677
# LinearSVC                                  0.964965              0.050992
# GradientBoostingClassifier                 0.908346              0.395506
# XGBClassifier                              0.924157              0.484076
# RandomForestClassifier                     0.916044              0.648452
# KNeighborsClassifier                       0.891045              0.446809
#
#                             Validation Macro F1  Test Accuracy  \
# LogisticRegression                     0.704239       0.950334
# MultinomialNB                          0.621705       0.943447
# SVC                                    0.781000       0.959933
# LinearSVC                              0.507343       0.935935
# GradientBoostingClassifier             0.683029       0.949082
# XGBClassifier                          0.728700       0.957012
# RandomForestClassifier                 0.813540       0.963689
# KNeighborsClassifier                   0.709134       0.952212
#
#                             Test Binary Recall  Test Macro Recall  \
# LogisticRegression                    0.927835           0.939317
# MultinomialNB                         1.000000           0.971426
# SVC                                   0.932886           0.946844
# LinearSVC                             1.000000           0.967874
# GradientBoostingClassifier            0.866667           0.908797
# XGBClassifier                         0.891156           0.925126
# RandomForestClassifier                0.865672           0.916826
# KNeighborsClassifier                  0.865079           0.909822
#
#                             Test Binary F1  Test Macro F1
# LogisticRegression                0.430622       0.702328
# MultinomialNB                     0.269542       0.620063
# SVC                               0.591489       0.785211
# LinearSVC                         0.083582       0.525195
# GradientBoostingClassifier        0.427230       0.700293
# XGBClassifier                     0.559829       0.768616
# RandomForestClassifier            0.666667       0.823733
# KNeighborsClassifier              0.487696       0.731316

# %% [markdown]
# ## Original data frame: Only Bigram

# %%
result_all_dict_bi = tfidf_pipeline(train_df, test_df, val_df, ngram_range=(2,2))
result_pd_bi = pd.DataFrame.from_dict(result_all_dict_bi, orient='index')
result_pd_bi
# Out:
# ----------------------------------------
# LogisticRegression  Accuracy Score : 94.03%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# MultinomialNB  Accuracy Score : 94.14%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# SVC  Accuracy Score : 94.53%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# LinearSVC  Accuracy Score : 93.59%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# GradientBoostingClassifier  Accuracy Score : 94.12%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# [16:47:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# ----------------------------------------
# XGBClassifier  Accuracy Score : 94.16%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# RandomForestClassifier  Accuracy Score : 95.41%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# KNeighborsClassifier  Accuracy Score : 94.16%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#                             Validation Accuracy  Validation Binary Recall  \
# LogisticRegression                     0.935699                  0.973684
# MultinomialNB                          0.936326                  1.000000
# SVC                                    0.941127                  0.984375
# LinearSVC                              0.930063                  1.000000
# GradientBoostingClassifier             0.935908                  0.974359
# XGBClassifier                          0.935908                  0.974359
# RandomForestClassifier                 0.948852                  0.980583
# KNeighborsClassifier                   0.936326                  1.000000
#
#                             Validation Macro Recall  Validation Binary F1  \
# LogisticRegression                         0.954540              0.193717
# MultinomialNB                              0.967901              0.203655
# SVC                                        0.962458              0.308824
# LinearSVC                                  0.964965              0.050992
# GradientBoostingClassifier                 0.954976              0.198433
# XGBClassifier                              0.954976              0.198433
# RandomForestClassifier                     0.964368              0.451902
# KNeighborsClassifier                       0.967901              0.203655
#
#                             Validation Macro F1  Test Accuracy  \
# LogisticRegression                     0.580116       0.940317
# MultinomialNB                          0.585246       0.941361
# SVC                                    0.639039       0.945326
# LinearSVC                              0.507343       0.935935
# GradientBoostingClassifier             0.582526       0.941152
# XGBClassifier                          0.582526       0.941569
# RandomForestClassifier                 0.712538       0.954090
# KNeighborsClassifier                   0.585246       0.941569
#
#                             Test Binary Recall  Test Macro Recall  \
# LogisticRegression                    0.972973           0.956518
# MultinomialNB                         1.000000           0.970434
# SVC                                   0.983607           0.964219
# LinearSVC                             1.000000           0.967874
# GradientBoostingClassifier            0.953488           0.947264
# XGBClassifier                         1.000000           0.970533
# RandomForestClassifier                0.980952           0.967220
# KNeighborsClassifier                  1.000000           0.970533
#
#                             Test Binary F1  Test Macro F1
# LogisticRegression                0.201117       0.585059
# MultinomialNB                     0.221607       0.595570
# SVC                               0.314136       0.642832
# LinearSVC                         0.083582       0.525195
# GradientBoostingClassifier        0.225275       0.597345
# XGBClassifier                     0.226519       0.598079
# RandomForestClassifier            0.483568       0.729773
# KNeighborsClassifier              0.226519       0.598079

# %% [markdown]
# ## Upsampled data frame: Only Unigram

# %%
# Upsampled data frame
result_all_dict_upsampled = tfidf_pipeline(train_upsampled, test_df, val_df)
# Out:
# ----------------------------------------
# LogisticRegression  Accuracy Score : 94.6%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# MultinomialNB  Accuracy Score : 90.9%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# SVC  Accuracy Score : 96.54%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# LinearSVC  Accuracy Score : 92.78%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# GradientBoostingClassifier  Accuracy Score : 93.55%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# [16:34:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# ----------------------------------------
# XGBClassifier  Accuracy Score : 92.7%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# RandomForestClassifier  Accuracy Score : 96.45%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# KNeighborsClassifier  Accuracy Score : 91.82%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792

# %%
result_pd_upsampled = pd.DataFrame.from_dict(result_all_dict_upsampled, orient='index')
result_pd_upsampled
# Out:
#                             Validation Accuracy  Validation Binary Recall  \
# LogisticRegression                     0.945303                  0.600000
# MultinomialNB                          0.913987                  0.447040
# SVC                                    0.962422                  0.940860
# LinearSVC                              0.927349                  0.496241
# GradientBoostingClassifier             0.931733                  0.523810
# XGBClassifier                          0.926305                  0.490486
# RandomForestClassifier                 0.962004                  0.837500
# KNeighborsClassifier                   0.911691                  0.419223
#
#                             Validation Macro Recall  Validation Binary F1  \
# LogisticRegression                         0.788813              0.652520
# MultinomialNB                              0.716649              0.582150
# SVC                                        0.952077              0.660377
# LinearSVC                                  0.738726              0.602740
# GradientBoostingClassifier                 0.744197              0.533524
# XGBClassifier                              0.732271              0.567931
# RandomForestClassifier                     0.903036              0.688356
# KNeighborsClassifier                       0.693452              0.492197
#
#                             Validation Macro F1  Test Accuracy  \
# LogisticRegression                     0.811417       0.945952
# MultinomialNB                          0.767105       0.909015
# SVC                                    0.820244       0.965359
# LinearSVC                              0.781379       0.927796
# GradientBoostingClassifier             0.748348       0.935518
# XGBClassifier                          0.763824       0.926962
# RandomForestClassifier                 0.834062       0.964524
# KNeighborsClassifier                   0.721919       0.918197
#
#                             Test Binary Recall  Test Macro Recall  \
# LogisticRegression                    0.571101           0.777286
# MultinomialNB                         0.411674           0.699438
# SVC                                   0.923497           0.945259
# LinearSVC                             0.476980           0.731194
# GradientBoostingClassifier            0.516216           0.743409
# XGBClassifier                         0.469979           0.724082
# RandomForestClassifier                0.818565           0.895342
# KNeighborsClassifier                  0.425577           0.699115
#
#                             Test Binary F1  Test Macro F1
# LogisticRegression                0.657860       0.814259
# MultinomialNB                     0.551440       0.750407
# SVC                               0.670635       0.826176
# LinearSVC                         0.599537       0.779929
# GradientBoostingClassifier        0.552822       0.759038
# XGBClassifier                     0.564677       0.762407
# RandomForestClassifier            0.695341       0.838253
# KNeighborsClassifier              0.508772       0.732078

# %% [markdown]
# ## Upsampled data frame: Only Bigram

# %%
result_all_dict_upsampled_bi = tfidf_pipeline(train_upsampled, test_df, val_df, ngram_range=(2,2))
result_pd_upsampled_bi = pd.DataFrame.from_dict(result_all_dict_bi, orient='index')
result_pd_upsampled_bi
# Out:
# ----------------------------------------
# LogisticRegression  Accuracy Score : 95.7%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# MultinomialNB  Accuracy Score : 93.34%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# SVC  Accuracy Score : 95.56%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# LinearSVC  Accuracy Score : 95.6%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# GradientBoostingClassifier  Accuracy Score : 94.37%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# [16:54:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "use_label" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# ----------------------------------------
# XGBClassifier  Accuracy Score : 94.03%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# RandomForestClassifier  Accuracy Score : 95.53%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#
# ----------------------------------------
# KNeighborsClassifier  Accuracy Score : 85.77%
# Recall_Score:  0.8650793650793651
# F1_Score:  0.48769574944071586
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      4666
#            1       0.34      0.87      0.49       126
#
#     accuracy                           0.95      4792
#    macro avg       0.67      0.91      0.73      4792
# weighted avg       0.98      0.95      0.96      4792
#                             Validation Accuracy  Validation Binary Recall  \
# LogisticRegression                     0.935699                  0.973684
# MultinomialNB                          0.936326                  1.000000
# SVC                                    0.941127                  0.984375
# LinearSVC                              0.930063                  1.000000
# GradientBoostingClassifier             0.935908                  0.974359
# XGBClassifier                          0.935908                  0.974359
# RandomForestClassifier                 0.948852                  0.980583
# KNeighborsClassifier                   0.936326                  1.000000
#
#                             Validation Macro Recall  Validation Binary F1  \
# LogisticRegression                         0.954540              0.193717
# MultinomialNB                              0.967901              0.203655
# SVC                                        0.962458              0.308824
# LinearSVC                                  0.964965              0.050992
# GradientBoostingClassifier                 0.954976              0.198433
# XGBClassifier                              0.954976              0.198433
# RandomForestClassifier                     0.964368              0.451902
# KNeighborsClassifier                       0.967901              0.203655
#
#                             Validation Macro F1  Test Accuracy  \
# LogisticRegression                     0.580116       0.940317
# MultinomialNB                          0.585246       0.941361
# SVC                                    0.639039       0.945326
# LinearSVC                              0.507343       0.935935
# GradientBoostingClassifier             0.582526       0.941152
# XGBClassifier                          0.582526       0.941569
# RandomForestClassifier                 0.712538       0.954090
# KNeighborsClassifier                   0.585246       0.941569
#
#                             Test Binary Recall  Test Macro Recall  \
# LogisticRegression                    0.972973           0.956518
# MultinomialNB                         1.000000           0.970434
# SVC                                   0.983607           0.964219
# LinearSVC                             1.000000           0.967874
# GradientBoostingClassifier            0.953488           0.947264
# XGBClassifier                         1.000000           0.970533
# RandomForestClassifier                0.980952           0.967220
# KNeighborsClassifier                  1.000000           0.970533
#
#                             Test Binary F1  Test Macro F1
# LogisticRegression                0.201117       0.585059
# MultinomialNB                     0.221607       0.595570
# SVC                               0.314136       0.642832
# LinearSVC                         0.083582       0.525195
# GradientBoostingClassifier        0.225275       0.597345
# XGBClassifier                     0.226519       0.598079
# RandomForestClassifier            0.483568       0.729773
# KNeighborsClassifier              0.226519       0.598079

# %% [markdown]
# # Generate other features (TBC)

# %%
# https://github.com/t-davidson/hate-speech-and-offensive-language/blob/master/classifier/final_classifier.ipynb

# get other features
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer as VS
from textstat.textstat import *

sentiment_analyzer = VS()

def count_twitter_objs(text_string):
    """
    Accepts a text string and replaces:
    1) urls with URLHERE
    2) lots of whitespace with one instance
    3) mentions with MENTIONHERE
    4) hashtags with HASHTAGHERE

    This allows us to get standardized counts of urls and mentions
    Without caring about specific people mentioned.
    
    Returns counts of urls, mentions, and hashtags.
    """
    space_pattern = '\s+'
    giant_url_regex = ('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|'
        '[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    mention_regex = '@[\w\-]+'
    hashtag_regex = '#[\w\-]+'
    parsed_text = re.sub(space_pattern, ' ', text_string)
    parsed_text = re.sub(giant_url_regex, 'URLHERE', parsed_text)
    parsed_text = re.sub(mention_regex, 'MENTIONHERE', parsed_text)
    parsed_text = re.sub(hashtag_regex, 'HASHTAGHERE', parsed_text)
    return(parsed_text.count('URLHERE'),parsed_text.count('MENTIONHERE'),parsed_text.count('HASHTAGHERE'))

def other_features(tweet):
    """This function takes a string and returns a list of features.
    These include Sentiment scores, Text and Readability scores,
    as well as Twitter specific features"""
    ##SENTIMENT
    sentiment = sentiment_analyzer.polarity_scores(tweet)
    
    words = preprocess(tweet) #Get text only
    
    syllables = textstat.syllable_count(words) #count syllables in words
    num_chars = sum(len(w) for w in words) #num chars in words
    num_chars_total = len(tweet)
    num_terms = len(tweet.split())
    num_words = len(words.split())
    avg_syl = round(float((syllables+0.001))/float(num_words+0.001),4)
    num_unique_terms = len(set(words.split()))
    
    ###Modified FK grade, where avg words per sentence is just num words/1
    FKRA = round(float(0.39 * float(num_words)/1.0) + float(11.8 * avg_syl) - 15.59,1)
    ##Modified FRE score, where sentence fixed to 1
    FRE = round(206.835 - 1.015*(float(num_words)/1.0) - (84.6*float(avg_syl)),2)
    
    twitter_objs = count_twitter_objs(tweet) #Count #, @, and http://
    retweet = 0
    if "rt" in words:
        retweet = 1
    features = [FKRA, FRE,syllables, avg_syl, num_chars, num_chars_total, num_terms, num_words,
                num_unique_terms, sentiment['neg'], sentiment['pos'], sentiment['neu'], sentiment['compound'],
                twitter_objs[2], twitter_objs[1],
                twitter_objs[0], retweet]
    #features = pandas.DataFrame(features)
    return features

def get_feature_array(tweets):
    feats=[]
    for t in tweets:
        feats.append(other_features(t))
    return np.array(feats)

# %%
other_features_names = ["FKRA", "FRE","num_syllables", "avg_syl_per_word", "num_chars", "num_chars_total", \
                        "num_terms", "num_words", "num_unique_words", "vader neg","vader pos","vader neu", "vader compound", \
                        "num_hashtags", "num_mentions", "num_urls", "is_retweet"]

feats = get_feature_array(tweets)
