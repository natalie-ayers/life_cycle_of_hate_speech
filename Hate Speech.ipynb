# %%
import pytrends
import pandas as pd
from pytrends.request import TrendReq
import matplotlib
import csv
from datetime import date
import time 
import requests
import warnings
warnings.filterwarnings('ignore')

pytrends = TrendReq(hl='en-US', tz=360)
# Out:
# /Users/sophiamlawer/opt/anaconda3/lib/python3.8/site-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
# INTEREST BY REGION - RELATIVE SEARCH VOLUME FOR ABORTION BY MONTH

keyword = ["nigger", "niggers", "kike", "chink"] 

dates = ['2018-01-01 2018-02-01', '2018-02-01 2018-03-01','2018-03-01 2018-04-01','2018-04-01 2018-05-01',
         '2018-05-01 2018-06-01','2018-06-01 2018-07-01','2018-07-01 2018-08-01','2018-08-01 2018-09-01',
         '2018-09-01 2018-10-01','2018-10-01 2018-11-01','2018-11-01 2018-12-01','2018-12-01 2019-01-01',
         '2019-01-01 2019-02-01','2019-02-01 2019-03-01','2019-03-01 2019-04-01','2019-04-01 2019-05-01',
         '2019-05-01 2019-06-01','2019-06-01 2019-07-01','2019-07-01 2019-08-01','2019-08-01 2019-09-01',
         '2019-09-01 2019-10-01','2019-10-01 2019-11-01','2019-11-01 2019-12-01','2019-12-01 2020-01-01',
         '2020-01-01 2020-02-01','2020-02-01 2020-03-01','2020-03-01 2020-04-01','2020-04-01 2020-05-01',
         '2020-05-01 2020-06-01','2020-06-01 2020-07-01','2020-07-01 2020-08-01','2020-08-01 2020-09-01',
         '2020-09-01 2020-10-01','2020-10-01 2020-11-01','2020-11-01 2020-12-01','2020-12-01 2021-01-01',
         '2021-01-01 2021-02-01','2021-02-01 2021-03-01','2021-03-01 2021-04-01','2021-04-01 2021-05-01',
         '2021-05-01 2021-06-01','2021-06-01 2021-07-01','2021-07-01 2021-08-01','2021-08-01 2021-09-01',
         '2021-09-01 2021-10-01','2021-10-01 2021-11-01','2021-11-01 2021-12-01','2021-12-01 2022-01-01'
]

#df_time = pd.DataFrame(columns = ['state', "nigger", "niggers", "kike", "chink","date_range'])

df_time = pd.DataFrame(columns = ['nigger', 'date_range'])

                                  
for by_month in dates:
    pytrends.build_payload(["nigger"], cat=0, timeframe=by_month, geo='US', gprop='')
    df_region = pytrends.interest_by_region(resolution="REGION", inc_low_vol=True, inc_geo_code=False)
    df_region["date_range"] = by_month
    df_time = pd.concat([df_time, df_region])

# %%
df_time['nigger'] =df_time['nigger'].astype(str).astype(int)
df_time['date'] = [x[:7] for x in df_time['date_range']]

df_time = df_time.drop(['date_range'], axis=1)
df_time = df_time.reset_index() 

pivot = pd.pivot_table(df_time, index='index', columns='date', values="nigger")
pivot.head()
# Out:
# date        2018-01  2018-02  2018-03  2018-04  2018-05  2018-06  2018-07  \
# index
# Alabama          71       96       78       72       66       60       91
# Alaska           99       71       42       61       85       68       48
# Arizona          47       41       44       53       37       48       53
# Arkansas         71       48       78      100       71       62       74
# California       36       45       42       44       44       34       46
#
# date        2018-08  2018-09  2018-10  ...  2021-03  2021-04  2021-05  \
# index                                  ...
# Alabama          69       58       61  ...       78       57       60
# Alaska           27       36       55  ...       97       69       63
# Arizona          40       60       48  ...       40       37       58
# Arkansas         44       99       51  ...       76       81       53
# California       33       51       40  ...       45       38       42
#
# ...

# %%
regiondf = pytrends.interest_by_region(resolution="REGION", inc_low_vol=True, inc_geo_code=False)

# %%
keyword = ["nigger", "niggers", "kike", "chink", "faggot"]

pytrends.build_payload(keyword, cat=0, timeframe='2013-09-01 2015-04-01', geo='US', gprop='')
interest_over_time_df = pytrends.interest_over_time()

# %%
interest_over_time_df
# Out:
#             nigger  niggers  kike  chink  faggot  isPartial
# date
# 2013-09-01      63       16     7      3      24      False
# 2013-09-08      54       12     5      3      19      False
# 2013-09-15      53       13     7      4      19      False
# 2013-09-22      52       13     5      3      19      False
# 2013-09-29      54       13     5      3      20      False
# ...            ...      ...   ...    ...     ...        ...
# 2015-03-01      55       14     8     11      20      False
# 2015-03-08      86       18     7      6      22      False
# 2015-03-15      71       18     7     19      20      False
# 2015-03-22      57       14     8     12      21      False
# 2015-03-29      59       15     8     11      21      False
#
# [83 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(15,10))


plt.plot(interest_over_time_df.index, interest_over_time_df["nigger"], label = "Anti-Black word")
# plt.plot(interest_over_time_df.index, interest_over_time_df["niggers"], label = "n-word plural")
plt.plot(interest_over_time_df.index, interest_over_time_df["kike"], label = "Anti-Semitic word")
plt.plot(interest_over_time_df.index, interest_over_time_df["chink"], label = "Anti-Asian word")
plt.plot(interest_over_time_df.index, interest_over_time_df["faggot"], label = "Anti-LGBT word")

plt.legend()
plt.show()
